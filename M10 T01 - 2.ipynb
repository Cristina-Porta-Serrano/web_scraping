# %% [markdown]
# ### Scrapy

# %%
import pandas as pd
import scrapy

# %%
from scrapy.crawler import CrawlerProcess


class StandingsSpider(scrapy.Spider):
    name = "standings"
    start_urls = ["https://www.formula1.com/en/results.html/2022/drivers.html" ]

    def parse(self, response):
          table = response.xpath('//*[contains(@class,"resultsarchive-table")]//tbody//tr')
      
          for standing in table:


            yield {
              'position': standing.xpath('td//text()')[0].extract(),
              'name': standing.xpath('td//text()')[3].extract(),
              'lastname': standing.xpath('td//text()')[5].extract(),
              'alias': standing.xpath('td//text()')[7].extract(),
              'country': standing.xpath('td//text()')[10].extract(),
              'car': standing.xpath('td//text()')[12].extract(),
              'points': standing.xpath('td//text()')[14].extract(),
            }
            

FILE_NAME = 'f1_standings_.csv'
SETTINGS = {
            'FEED_FORMAT': 'csv',
            'FEED_URI': FILE_NAME,
            'DOWNLOAD_DELAY': 1,
            } 
process = CrawlerProcess({
    'USER_AGENT': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.5005.63 Safari/537.36'
})
# Out:
# 2022-09-25 19:10:41 [scrapy.utils.log] INFO: Scrapy 2.6.2 started (bot: scrapybot)
# 2022-09-25 19:10:41 [scrapy.utils.log] INFO: Versions: lxml 4.6.3.0, libxml2 2.9.12, cssselect 1.1.0, parsel 1.6.0, w3lib 2.0.1, Twisted 22.8.0, Python 3.9.7 (default, Sep 16 2021, 16:59:28) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 21.0.0 (OpenSSL 1.1.1l  24 Aug 2021), cryptography 3.4.8, Platform Windows-10-10.0.19043-SP0

# %%
process = CrawlerProcess(SETTINGS)
process.crawl(StandingsSpider)
process.start()
# Out:
# 2022-09-25 19:10:43 [scrapy.utils.log] INFO: Scrapy 2.6.2 started (bot: scrapybot)
# 2022-09-25 19:10:43 [scrapy.utils.log] INFO: Versions: lxml 4.6.3.0, libxml2 2.9.12, cssselect 1.1.0, parsel 1.6.0, w3lib 2.0.1, Twisted 22.8.0, Python 3.9.7 (default, Sep 16 2021, 16:59:28) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 21.0.0 (OpenSSL 1.1.1l  24 Aug 2021), cryptography 3.4.8, Platform Windows-10-10.0.19043-SP0
# 2022-09-25 19:10:43 [scrapy.crawler] INFO: Overridden settings:
# {'DOWNLOAD_DELAY': 1}
# 2022-09-25 19:10:43 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2022-09-25 19:10:43 [scrapy.extensions.telnet] INFO: Telnet Password: e24525ac940f27a9
# 2022-09-25 19:10:43 [py.warnings] WARNING: C:\Users\Pereira\anaconda3\lib\site-packages\scrapy\extensions\feedexport.py:289: ScrapyDeprecationWarning: The `FEED_URI` and `FEED_FORMAT` settings have been deprecated in favor of the `FEEDS` setting. Please see the `FEEDS` setting docs for more details
#   exporter = cls(crawler)
#
# 2022-09-25 19:10:43 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2022-09-25 19:10:44 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2022-09-25 19:10:44 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2022-09-25 19:10:44 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2022-09-25 19:10:44 [scrapy.core.engine] INFO: Spider opened
# 2022-09-25 19:10:44 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2022-09-25 19:10:44 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6039
# 2022-09-25 19:10:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.formula1.com/en/results.html/2022/drivers.html> (referer: None)
# 2022-09-25 19:10:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.formula1.com/en/results.html/2022/drivers.html>
# {'position': '1', 'name': 'Max', 'lastname': 'Verstappen', 'alias': 'VER', 'country': 'NED', 'car': 'Red Bull Racing RBPT', 'points': '335'}
# 2022-09-25 19:10:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.formula1.com/en/results.html/2022/drivers.html>
# {'position': '2', 'name': 'Charles', 'lastname': 'Leclerc', 'alias': 'LEC', 'country': 'MON', 'car': 'Ferrari', 'points': '219'}
# 2022-09-25 19:10:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.formula1.com/en/results.html/2022/drivers.html>
# {'position': '3', 'name': 'Sergio', 'lastname': 'Perez', 'alias': 'PER', 'country': 'MEX', 'car': 'Red Bull Racing RBPT', 'points': '210'}
# 2022-09-25 19:10:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.formula1.com/en/results.html/2022/drivers.html>
# {'position': '4', 'name': 'George', 'lastname': 'Russell', 'alias': 'RUS', 'country': 'GBR', 'car': 'Mercedes', 'points': '203'}
# 2022-09-25 19:10:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.formula1.com/en/results.html/2022/drivers.html>
# {'position': '5', 'name': 'Carlos', 'lastname': 'Sainz', 'alias': 'SAI', 'country': 'ESP', 'car': 'Ferrari', 'points': '187'}
# 2022-09-25 19:10:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.formula1.com/en/results.html/2022/drivers.html>
# {'position': '6', 'name': 'Lewis', 'lastname': 'Hamilton', 'alias': 'HAM', 'country': 'GBR', 'car': 'Mercedes', 'points': '168'}
# 2022-09-25 19:10:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.formula1.com/en/results.html/2022/drivers.html>
# {'position': '7', 'name': 'Lando', 'lastname': 'Norris', 'alias': 'NOR', 'country': 'GBR', 'car': 'McLaren Mercedes', 'points': '88'}
# 2022-09-25 19:10:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.formula1.com/en/results.html/2022/drivers.html>
# {'position': '8', 'name': 'Esteban', 'lastname': 'Ocon', 'alias': 'OCO', 'country': 'FRA', 'car': 'Alpine Renault', 'points': '66'}
# 2022-09-25 19:10:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.formula1.com/en/results.html/2022/drivers.html>
# {'position': '9', 'name': 'Fernando', 'lastname': 'Alonso', 'alias': 'ALO', 'country': 'ESP', 'car': 'Alpine Renault', 'points': '59'}
# 2022-09-25 19:10:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.formula1.com/en/results.html/2022/drivers.html>
# {'position': '10', 'name': 'Valtteri', 'lastname': 'Bottas', 'alias': 'BOT', 'country': 'FIN', 'car': 'Alfa Romeo Ferrari', 'points': '46'}
# 2022-09-25 19:10:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.formula1.com/en/results.html/2022/drivers.html>
# {'position': '11', 'name': 'Pierre', 'lastname': 'Gasly', 'alias': 'GAS', 'country': 'FRA', 'car': 'AlphaTauri RBPT', 'points': '22'}
# 2022-09-25 19:10:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.formula1.com/en/results.html/2022/drivers.html>
# {'position': '12', 'name': 'Kevin', 'lastname': 'Magnussen', 'alias': 'MAG', 'country': 'DEN', 'car': 'Haas Ferrari', 'points': '22'}
# 2022-09-25 19:10:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.formula1.com/en/results.html/2022/drivers.html>
# {'position': '13', 'name': 'Sebastian', 'lastname': 'Vettel', 'alias': 'VET', 'country': 'GER', 'car': 'Aston Martin Aramco Mercedes', 'points': '20'}
# 2022-09-25 19:10:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.formula1.com/en/results.html/2022/drivers.html>
# {'position': '14', 'name': 'Daniel', 'lastname': 'Ricciardo', 'alias': 'RIC', 'country': 'AUS', 'car': 'McLaren Mercedes', 'points': '19'}
# 2022-09-25 19:10:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.formula1.com/en/results.html/2022/drivers.html>
# {'position': '15', 'name': 'Mick', 'lastname': 'Schumacher', 'alias': 'MSC', 'country': 'GER', 'car': 'Haas Ferrari', 'points': '12'}
# 2022-09-25 19:10:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.formula1.com/en/results.html/2022/drivers.html>
# {'position': '16', 'name': 'Yuki', 'lastname': 'Tsunoda', 'alias': 'TSU', 'country': 'JPN', 'car': 'AlphaTauri RBPT', 'points': '11'}
# 2022-09-25 19:10:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.formula1.com/en/results.html/2022/drivers.html>
# {'position': '17', 'name': 'Zhou', 'lastname': 'Guanyu', 'alias': 'ZHO', 'country': 'CHN', 'car': 'Alfa Romeo Ferrari', 'points': '6'}
# 2022-09-25 19:10:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.formula1.com/en/results.html/2022/drivers.html>
# {'position': '18', 'name': 'Lance', 'lastname': 'Stroll', 'alias': 'STR', 'country': 'CAN', 'car': 'Aston Martin Aramco Mercedes', 'points': '5'}
# 2022-09-25 19:10:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.formula1.com/en/results.html/2022/drivers.html>
# {'position': '19', 'name': 'Alexander', 'lastname': 'Albon', 'alias': 'ALB', 'country': 'THA', 'car': 'Williams Mercedes', 'points': '4'}
# 2022-09-25 19:10:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.formula1.com/en/results.html/2022/drivers.html>
# {'position': '20', 'name': 'Nyck', 'lastname': 'De Vries', 'alias': 'DEV', 'country': 'NED', 'car': 'Williams Mercedes', 'points': '2'}
# 2022-09-25 19:10:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.formula1.com/en/results.html/2022/drivers.html>
# {'position': '21', 'name': 'Nicholas', 'lastname': 'Latifi', 'alias': 'LAT', 'country': 'CAN', 'car': 'Williams Mercedes', 'points': '0'}
# 2022-09-25 19:10:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.formula1.com/en/results.html/2022/drivers.html>
# {'position': '22', 'name': 'Nico', 'lastname': 'Hulkenberg', 'alias': 'HUL', 'country': 'GER', 'car': 'Aston Martin Aramco Mercedes', 'points': '0'}
# 2022-09-25 19:10:45 [scrapy.core.engine] INFO: Closing spider (finished)
# 2022-09-25 19:10:45 [scrapy.extensions.feedexport] INFO: Stored csv feed (22 items) in: f1_standings_.csv
# 2022-09-25 19:10:45 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 253,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 35438,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'elapsed_time_seconds': 0.433751,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2022, 9, 25, 17, 10, 45, 420299),
#  'httpcompression/response_bytes': 222750,
#  'httpcompression/response_count': 1,
#  'item_scraped_count': 22,
#  'log_count/DEBUG': 24,
#  'log_count/INFO': 11,
#  'log_count/WARNING': 1,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2022, 9, 25, 17, 10, 44, 986548)}
# 2022-09-25 19:10:45 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
f1_standings_ = pd.read_csv('f1_standings_.csv')
f1_standings_
# Out:
#     position       name    lastname alias country  \
# 0          1        Max  Verstappen   VER     NED
# 1          2    Charles     Leclerc   LEC     MON
# 2          3     Sergio       Perez   PER     MEX
# 3          4     George     Russell   RUS     GBR
# 4          5     Carlos       Sainz   SAI     ESP
# 5          6      Lewis    Hamilton   HAM     GBR
# 6          7      Lando      Norris   NOR     GBR
# 7          8    Esteban        Ocon   OCO     FRA
# 8          9   Fernando      Alonso   ALO     ESP
# 9         10   Valtteri      Bottas   BOT     FIN
# 10        11     Pierre       Gasly   GAS     FRA
# 11        12      Kevin   Magnussen   MAG     DEN
# 12        13  Sebastian      Vettel   VET     GER
# 13        14     Daniel   Ricciardo   RIC     AUS
# 14        15       Mick  Schumacher   MSC     GER
# 15        16       Yuki     Tsunoda   TSU     JPN
# 16        17       Zhou      Guanyu   ZHO     CHN
# 17        18      Lance      Stroll   STR     CAN
# 18        19  Alexander       Albon   ALB     THA
# 19        20       Nyck    De Vries   DEV     NED
# 20        21   Nicholas      Latifi   LAT     CAN
# 21        22       Nico  Hulkenberg   HUL     GER
#
#                              car  points
# 0           Red Bull Racing RBPT     335
# 1                        Ferrari     219
# 2           Red Bull Racing RBPT     210
# 3                       Mercedes     203
# 4                        Ferrari     187
# 5                       Mercedes     168
# 6               McLaren Mercedes      88
# 7                 Alpine Renault      66
# 8                 Alpine Renault      59
# 9             Alfa Romeo Ferrari      46
# 10               AlphaTauri RBPT      22
# 11                  Haas Ferrari      22
# 12  Aston Martin Aramco Mercedes      20
# 13              McLaren Mercedes      19
# 14                  Haas Ferrari      12
# 15               AlphaTauri RBPT      11
# 16            Alfa Romeo Ferrari       6
# 17  Aston Martin Aramco Mercedes       5
# 18             Williams Mercedes       4
# 19             Williams Mercedes       2
# 20             Williams Mercedes       0
# 21  Aston Martin Aramco Mercedes       0

# %% [markdown]
# ## Conclusions

# %% [markdown]
# - We used three of the most common libraries to scrape websites, **BeautifulSoup, Selenium and Scrapy**. We scraped different websites with different features to have a wider vision of what we can achieve using these libraries.
#
#
# - The use of the libraries requires a minimum knowledge of HTML.
#
#
# - We have achieved the same result using the three libraries, however, Beautifulsoup has been more efficient since its handling (and learning curve) make it a more user-friendly tool. On another hand, Scrapy is much more advanced and it is mostly used in more complex projects.
